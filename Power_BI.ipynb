# %% [markdown]
# <a href="https://colab.research.google.com/github/jabsolo73/Data-Processing-teachings/blob/main/Power_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Power Query Editor (1–15)
# 1. What is Power Query Editor?
# - Load sample data -> Select table -> Click Transform
# - Known as Data preparation tool in Power BI
# - General View of Data and arrange data
#
# 2. What is the purpose of Power Query in Power BI?
# - Statistical actions on numerical columns and many more transform basic operations can be performed
# - Manipulation of rows and columns, and use merge techniques
# 3. Explain the ETL process in Power Query.
# - ETL: Extract Transform Load
# - Extract is a method of fetching the input file from any source
# - Transform is a process of preprocessing records and features
# - Load is a process of pushing the preprocessed and analyzed structure of dataset and loading into power bi Desktop(Close & Apply)
# 4.   What are Applied Steps?
# - Applied step is a area which tells out timely action , shows and can be ready to undone any time in Query setting box
# 5.   What is Query Folding?
# -  it is the process of pushing data transformations upstream to the source system rather than processing them downstream in the client application.
# - Step 1: Connect to a Foldable Data Source
# - Step 2 :Put your "Filters" and "Removals" First(applied steps)
# - Step 3: Check if it is Working(If View Native Query is active and clickable, your steps are folding! Clicking it will show you the SQL code running on the server.)
#
# 6.   What is the difference between Duplicate and Reference queries?
# - At any place when right clicked on a table , Click Duplicate and copy is create for decoy purpose no changes made in either affects either
# - If right click -> reference creates a linked table where in parent any changes reflects in reference table too
# 7.   What is the difference between Merge and Append?
# - Can find in Power Query Editor Home TAB
# - Merge joins table horizontally using joins and can merge in same table or btw 2 tables
# - Append Concats rows from two or more tables into a single table
# 8.   How do you remove duplicate rows?
# - Using power Query editor, Transform -> Home tab -> Remove rows -> Remove Duplicates
# - Keeps the first occurance removes rest
# 9.   What is the purpose of the Conditional Column?
# - Open Power Query Editor -> Add Column Tab-> Conditional column icon
# - Add a condiotional column based on comparison operators from other columns or values
# 10. How do you create a Custom Column?
# - Open Power Query Editor -> Add Column Tab-> Custom column icon
# - Create new name -> select columns and perform user defined actions
# - ex: new column = sales - netprofit
# 11. What is the difference between Pivot and Unpivot?
#  - Power Query Editor -> Transform Tab -> Pivot column icon-> select column -> Rows becomes columns
#  - Power Query Editor -> Transform Tab -> unPivot column icon-> select column ->columns becomes rows
# 12. How do you replace errors in a column?
# - Power Query Editor -> right click a column header -> replace error(if it has error values into 0 or null )-> give a new value
# 13. Why is changing the data type important?
# - Changing data type is important for further calculation and date columns too so that it doesn't clash with any future universal header type format specific pre-defined operations
# 14. What is the M language?
# - Used by Power query generated  in backgroundafter any actions done, can be seen in the formula bar
# 15. What is the difference between Close and Close & Apply?
# - Close just closes the query editor
# - Close and apply pushes data frame into power bi desktop

# %% [markdown]
# Data Modeling (16–25)
#
# 16. What is data modeling?
# - Building relationship between tables
# 17. What is the difference between a Fact table and a Dimension table?
# - Fact table stores numerical
# - Dimension table stores descriptive
# 18. What is a Star Schema?
# - one Fact table in the center connected directly to multiple Dimension tables.
# 19. What is a Snowflake Schema?
# - similar to a Star Schema, but the Dimension tables are further split into additional related tables.
# 20. Why is Star Schema preferred in Power BI?
# - More speed and easier to understand
# 21. Explain one-to-one, one-to-many, and many-to-many relationships.
# - 1 - 1: One record in Table A matches only one record in Table B
# - 1 - many: One record in Table A matches many records in Table B, but those records link back to only one entry in Table A.
# - many - many:  Multiple records in Table A can connect to multiple records in Table B.
# 22. What is the difference between Active and Inactive relationships?
# - Active: Used by default for all standard visual filters and calculations. Only one active path is allowed between any two tables. Shown as a solid line.
# - Inactive: : Stored in the data model as an alternate path, but do not pass filters on their own. Must be turned on manually inside a measure using a function like USERELATIONSHIP. Shown as a dashed or dotted line.
# 23. What is Cross Filter Direction?
# - It can be selected when creating a relationship
# - controls how filters flow between connected data tables: single-direction and both (bi-directional)
# 24. What is a Date Table, and why is it required?
# - It is a seperate table consist of continuous periodic date values each row
# - Used for Time intelligence function most
# 25. What is the difference between Import mode and DirectQuery?
# - Import mode: copies and stores data into Power BI’s in-memory storage(cloud)
# - Direct Query: leaves database in the source and queries it live(data source)

# %% [markdown]
# Measures & Calculated Columns (26–30)
#
# 26. What is the difference between a Measure and a Calculated Column?
# - Measure column: not a column but created basis  of calculation
# - Calculated column: creates a new column based on user defined actions on existing columns
# 27. When should you use a Measure instead of a Calculated Column?
# - When we need only a value not as a column itself can be viewed in cards visual
# 28. What is the difference between a Calculated Table and a Calculated Column?
# - Calculated table: Creates an entirely new table using DAX Methods.
# - Calculated column: Adds user defined action new column to an existing table.
# 29. Where are Measures stored in the model?
# - It is stored not as a table but as a calculator symbol holding calculated single value
# 30. Can a Measure be used as a slicer? Why or why not?
# - No, Slicer needs columns to perform the filter where measure is just a value

# %% [markdown]
# DAX Aggregate Functions (31–36)
#
# 31. What is DAX?
# - Dax: Data Analysis expression
# - It is a Formula language where predefined syntax are there we give the parameters
# - Used to create measure, calculated column/table
# 32. What is the difference between SUM() and SUMX()?
# - SUM(): Column level action , add values from one column
# - SUMX(): Row level action and by column
# 33. What is the difference between AVERAGE() and AVERAGEX()?
# - Average(): finds average of single column
# - Averagex(): performs expression then does average
# 34. What is the difference between COUNT(), COUNTA(), and COUNTROWS()?
# - Count():Counts only numeric values, single value
# - CountA():Counts text and string, Counts all non-empty values.
# -Countrows():Counts the number of rows in a table.
# 35. When would you use MIN() and MAX()?
# - Min and Max are used to return mininum and maximum of a column
# 36. Explain the purpose of DISTINCTCOUNT().
# - counts unique values.

# %% [markdown]
# Filter & Context Functions (37–43)
#
# 37. What is Filter Context?
# - Filter Context is the collection of filters applied to a calculation. Measures automatically recalculate based on the current filter context.
# - Goes model level too and changes at relationship level too
# 38. What is Row Context?
# - works row by row
# - can access the value of each column of only the iterated table. Columns in different tables are not affected by the presence of a row context, even if there are relationships linking the tables together.
# 39. What is the FILTER() function?
# - returns only the rows that satisfy a condition.
# - FILTER() returns a filtered table based on a condition and is commonly used inside CALCULATE() and iterator functions.
# 40. What is the CALCULATE() function?
# - it is a overall guiding where inside this function expression and filters are given
# 41. Why is CALCULATE() considered the most powerful DAX function?
# - can concat multiple expression and filters
# 42. What is the difference between ALL() and FILTER()?
# - ALL():  tells Power BI to ignore any filters currently applied, commonly used inside CALCULATE() to create denominators for percentages
# - Filter(): is an iterator function. It looks at a table, evaluates a specific true/false condition for every single row, and returns only the rows that match.
# 43. What is the difference between ALL(), ALLEXCEPT(), and REMOVEFILTERS()?
# - ALL()	Removes all filters from a table or specified columns and returns all rows
# - ALLEXCEPT()	Removes all filters except the specified columns
# - REMOVEFILTERS()	Removes filters from the specified table or columns without returning a table for iteration

# %% [markdown]
# Logical Functions (44–48)
#
# 44. What is the IF() function?
# - The IF() function checks a condition. If the condition is TRUE, it returns one value.
# - If the condition is FALSE, it returns another value.
# 45. What is the difference between IF() and SWITCH()?
# - IF(): Best for one or two conditions.
# - SWITCH(): is cleaner when you have many possible results and easier to read than using nested IF
# 46. What is the purpose of AND()?
# - returns true only if both conditions are true
# 47. What is the purpose of OR()?
# - returns if either one condition is true
# 48. What is the purpose of NOT()?
# - reverses a logical value.
# - TRUE becomes FALSE.
# - FALSE becomes TRUE.

# %% [markdown]
# Date & Time / Time Intelligence (49–55)
#
# 49. What is the purpose of TODAY() and NOW()?
# - TODAY() Returns today's date only.
# - NOW() Returns the current date and current time.
# 50. What is the difference between YEAR(), MONTH(), and DAY()?
# - From the date column
# - year: Returns the year.
# - month: Returns the month number.
# - day: Returns the day of the month.
# 51. What is TOTALYTD()? Give an example.
# - calculates Year-to-Date (YTD) totals
# - YTD Sales =
# TOTALYTD(
#     SUM(Sales[Sales]),
#     'Date'[Date]
# )
# 52. What is TOTALMTD()?
# - calculates Month-to-Date totals
# - returns the cumulative total from the beginning of the current month up to the selected date.
# 53. What is TOTALQTD()?
# - calculates Quarter-to-Date totals.
# - returns the cumulative total from the beginning of the current quarter up to the selected date.
# 54. What are Time Intelligence functions, and what is required before using them?
# - Time Intelligence functions perform calculations over dates
# - A Date column is must
# 55. What is the difference between YTD, MTD, and QTD?
# - YTD: Sums your sales all the way from January 1st, 2026 to July 28th, 2026.(year wise)
# - MTD:Sums your sales from July 1st, 2026 to July 28th, 2026.(month wise)
# - QTD:July is the start of Quarter 3. Therefore, QTD sums your sales from July 1st, 2026 to July 28th, 2026 (in this specific case, it matches MTD because July is the first month of the quarter).

# %% [markdown]
# Visualizations (56–60)
#
# 56. When should you use a Bar Chart instead of a Column Chart?
# - it is just a matter of view perception and orientation
# - Both charts compare values across categories.
# - Bar is horizontal
# - Column is vertical
# 57. When is a Pie Chart appropriate, and when should it be avoided?
# - when need of majority and minority of involment in percentage for categorical columns with values as range with percentage upto 100
# - it should be avoided when more clustered catergories are there like 50 or 100 as it will be conjested
# 58. What is the difference between a Pie Chart and a Donut Chart?
# - pie chart and donut chart is same defenition except donot has empty space in btw maybe for chart name can be added as text box
# 59. Which visual would you use to show a trend over time? Why?
# - Use a Line Chart because it clearly shows trends, increases, decreases, and patterns over time.
# 60. Name five Power BI visuals and explain one use case for each
# - Cards: Display one KPI(measures)
# - Table: Display detailed records, same as adding rows and columns for visuals
# - Area Chart: graph can be overfilled with categories each color and lines are sharp, can be used for category with trend analysis but with lines are filled with intensity visual
# - Pie chart- use for categorial view on percentage level
# - Line Chart: shows trends over lines linear approach for sales over time
