# %% [markdown]
# <a href="https://colab.research.google.com/github/jabsolo73/Data-Processing-teachings/blob/main/Mini_Task_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Cleaning**

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Creating DataFrame into a Dataset**

# %%
data=dt = {
    'Movie': ['Shyam Singha Roy','Jersey','Vaaranam Aayiram','Minnale','Virumaandi','Bombay','Missing'
              ,'Theri','Coolie','Shiddat','KGF','Amaran'],
    'Hero': ['Naani',None,'Suriya','Madhavan','Missing','NA',np.nan,'Vijay','Rajini'
             ,'Sunny Kaushal','Yash','SK'],
    'Heroine':['Sai Pallavi','NA',np.nan,'Reema Sen','Missing','Manisha koriala','NA','Samantha','NA',
              'Radhika Madan','Srinidhi Shetty','Sai Pallavi'],
    'Rating':['NA',10,9.5,np.nan,'Missing',8,None,9.9,3.9,10,9.5,np.nan]
    ,'Box_Office_in_CRORE':[60,90,50,39,20,10,'Missing',100,90,100,150,120]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#                Movie           Hero          Heroine   Rating  \
# 0   Shyam Singha Roy          Naani      Sai Pallavi       NA
# 1             Jersey           None               NA       10
# 2   Vaaranam Aayiram         Suriya              NaN      9.5
# 3            Minnale       Madhavan        Reema Sen      NaN
# 4         Virumaandi        Missing          Missing  Missing
# 5             Bombay             NA  Manisha koriala        8
# 6            Missing            NaN               NA     None
# 7              Theri          Vijay         Samantha      9.9
# 8             Coolie         Rajini               NA      3.9
# 9            Shiddat  Sunny Kaushal    Radhika Madan       10
# 10               KGF           Yash  Srinidhi Shetty      9.5
# 11            Amaran             SK      Sai Pallavi      NaN
#
#    Box_Office_in_CRORE
# 0                   60
# 1                   90
# 2                   50
# 3                   39
# 4                   20
# 5                   10
# 6              Missing
# 7                  100
# 8                   90
# 9                  100
# 10                 150
# 11                 120

# %% [markdown]
# **Printing Columns**

# %%
df.columns
# Out:
# Index(['Movie', 'Hero', 'Heroine', 'Rating', 'Box_Office_in_CRORE'], dtype='object')

# %% [markdown]
# **Data Types**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Movie                12 non-null     object
#  1   Hero                 10 non-null     object
#  2   Heroine              11 non-null     object
#  3   Rating               9 non-null      object
#  4   Box_Office_in_CRORE  12 non-null     object
# dtypes: object(5)
# memory usage: 612.0+ bytes

# %% [markdown]
# **Print Top and Bottom**

# %%
df.head(5)
# Out:
#               Movie      Hero      Heroine   Rating Box_Office_in_CRORE
# 0  Shyam Singha Roy     Naani  Sai Pallavi       NA                  60
# 1            Jersey      None           NA       10                  90
# 2  Vaaranam Aayiram    Suriya          NaN      9.5                  50
# 3           Minnale  Madhavan    Reema Sen      NaN                  39
# 4        Virumaandi   Missing      Missing  Missing                  20

# %%
df.tail(5)
# Out:
#       Movie           Hero          Heroine Rating Box_Office_in_CRORE
# 7     Theri          Vijay         Samantha    9.9                 100
# 8    Coolie         Rajini               NA    3.9                  90
# 9   Shiddat  Sunny Kaushal    Radhika Madan     10                 100
# 10      KGF           Yash  Srinidhi Shetty    9.5                 150
# 11   Amaran             SK      Sai Pallavi    NaN                 120

# %% [markdown]
# **Range of Features and Records**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.size
# Out:
# 60

# %%
df.shape
# Out:
# (12, 5)

# %% [markdown]
#  **NULL VALUE PRE PROCESSING**

# %%
df.isnull().sum()
# Out:
# Movie                  0
# Hero                   2
# Heroine                1
# Rating                 3
# Box_Office_in_CRORE    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Movie                  0
# Hero                   2
# Heroine                1
# Rating                 3
# Box_Office_in_CRORE    0
# dtype: int64

# %%
df = df.replace([None,'NA',"Missing"],np.nan)

# %%
df.isnull().sum()
# Out:
# Movie                  1
# Hero                   4
# Heroine                5
# Rating                 5
# Box_Office_in_CRORE    1
# dtype: int64

# %%
df
# Out:
#                Movie           Hero          Heroine  Rating  \
# 0   Shyam Singha Roy          Naani      Sai Pallavi     NaN
# 1             Jersey            NaN              NaN    10.0
# 2   Vaaranam Aayiram         Suriya              NaN     9.5
# 3            Minnale       Madhavan        Reema Sen     NaN
# 4         Virumaandi            NaN              NaN     NaN
# 5             Bombay            NaN  Manisha koriala     8.0
# 6                NaN            NaN              NaN     NaN
# 7              Theri          Vijay         Samantha     9.9
# 8             Coolie         Rajini              NaN     3.9
# 9            Shiddat  Sunny Kaushal    Radhika Madan    10.0
# 10               KGF           Yash  Srinidhi Shetty     9.5
# 11            Amaran             SK      Sai Pallavi     NaN
#
#     Box_Office_in_CRORE
# 0                  60.0
# 1                  90.0
# 2                  50.0
# 3                  39.0
# 4                  20.0
# 5                  10.0
# 6                   NaN
# 7                 100.0
# 8                  90.0
# 9                 100.0
# 10                150.0
# 11                120.0

# %%
df.describe(include='all')
# Out:
#                    Movie   Hero      Heroine     Rating  Box_Office_in_CRORE
# count                 11      8            7   7.000000            11.000000
# unique                11      8            6        NaN                  NaN
# top     Shyam Singha Roy  Naani  Sai Pallavi        NaN                  NaN
# freq                   1      1            2        NaN                  NaN
# mean                 NaN    NaN          NaN   8.685714            75.363636
# std                  NaN    NaN          NaN   2.222183            43.294971
# min                  NaN    NaN          NaN   3.900000            10.000000
# 25%                  NaN    NaN          NaN   8.750000            44.500000
# 50%                  NaN    NaN          NaN   9.500000            90.000000
# 75%                  NaN    NaN          NaN   9.950000           100.000000
# max                  NaN    NaN          NaN  10.000000           150.000000

# %%
df.dtypes
#automatically changed
# Out:
# Movie                   object
# Hero                    object
# Heroine                 object
# Rating                 float64
# Box_Office_in_CRORE    float64
# dtype: object
